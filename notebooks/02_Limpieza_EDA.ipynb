# %% [markdown]
# # Tema del Proyecto:
# ### Sistema de Detección y Recomendación para Trastornos del Sueño usando Machine Learning
#
# ## Título:
# ### **Dormir Mejor con Datos: Predicción de Trastornos del Sueño y Recomendaciones Personalizadas**
#
# Este proyecto tiene como objetivo desarrollar un sistema inteligente que permita detectar trastornos del sueño a partir de datos personales, de estilo de vida y clínicos, utilizando algoritmos de aprendizaje automático. El enfoque se basa en un proceso de dos etapas:
#
# 1. **Detección binaria:** determinar si una persona presenta o no un trastorno del sueño.
# 2. **Clasificación del tipo de trastorno:** en caso afirmativo, identificar de qué trastorno se trata (por ejemplo, insomnio, apnea, narcolepsia, etc.).
#
# Posteriormente, se propone construir una **aplicación de recomendaciones personalizadas**, que, según el tipo de trastorno diagnosticado por el modelo, ofrezca sugerencias prácticas y adaptadas para mejorar la calidad del descanso.
#
# Para llevar a cabo este proyecto, se han utilizado **dos conjuntos de datos de Kaggle**:
#
# - [Sleep Health and Lifestyle Dataset](https://www.kaggle.com/datasets/uom190346a/sleep-health-and-lifestyle-dataset): contiene datos sobre ocupación, hábitos diarios, duración y calidad del sueño, nivel de estrés, frecuencia cardíaca, IMC, entre otros.
#
# - [Sleep Disorder Diagnostic Dataset](https://www.kaggle.com/datasets/ziya07/sleep-disorder-diagnostic-dataset): aporta datos clínicos como el tipo de trastorno diagnosticado, puntuaciones AHI, niveles de oxígeno en sangre (SaO2) y confirmaciones médicas.
#
# ---
#
# ## Objetivos del Proyecto:
#
# - **Detectar la presencia de trastornos del sueño:** Predecir si un individuo presenta o no un trastorno, a partir de datos demográficos, de estilo de vida y clínicos.
# - **Clasificar el tipo de trastorno:** Si se detecta un trastorno, identificar si se trata de insomnio, apnea del sueño, narcolepsia, síndrome de piernas inquietas, etc.
# - **Identificar factores clave:** Analizar qué variables tienen mayor influencia en la aparición de cada tipo de trastorno.
# - **Diseñar un sistema de recomendaciones inteligentes:** Proporcionar recomendaciones personalizadas y prácticas para cada paciente, en función del trastorno detectado y sus características individuales.
# - **Prototipar una aplicación útil para pacientes y profesionales:** Crear una interfaz que permita ingresar datos y recibir predicciones y sugerencias específicas para mejorar el sueño.
#
# ---
#
# ### Variable Objetivo (Target)
#
# - **Etapa 1:** `Tiene_Trastorno` → variable binaria: *Sí / No*
# - **Etapa 2:** `Sleep_Disorder` → variable categórica con clases como: *Insomnio*, *Apnea del Sueño*, *Narcolepsia*, *Síndrome de Piernas Inquietas*, etc.
#
# ---
#
# ### ¿Qué se puede predecir?:
#
# - **Problema de clasificación jerárquica:**
#   - **Primera predicción:** si una persona tiene o no un trastorno del sueño.
#   - **Segunda predicción (condicional):** en caso afirmativo, determinar el tipo específico de trastorno.
#
# - **Relevancia médica y social:**
#   - Este enfoque puede facilitar una detección temprana de trastornos del sueño, lo cual es clave para evitar complicaciones médicas, mejorar la calidad de vida y reducir el impacto en la productividad y salud mental.
#
# - **Aplicabilidad práctica:**
#   - El modelo servirá como base para una aplicación que no solo prediga el trastorno, sino que también brinde recomendaciones como:
#     - Cambios en la rutina del sueño.
#     - Ejercicios de relajación.
#     - Recomendaciones sobre actividad física, dieta o visitas médicas.
#     - Alertas para síntomas que requieren atención profesional.
#
# ---
#
# ### Técnicas a utilizar:
#
# - Modelos de clasificación como:
#   - `Random Forest`, `XGBoost`, redes neuronales.
# - Evaluación mediante métricas balanceadas (f1-score, recall por clase).
# - Posibles técnicas de preprocesamiento:
#   - Balanceo de clases.
#   - Selección de características relevantes.
# - Desarrollo posterior de una interfaz o prototipo de app para visualizar resultados y recomendaciones.

# %% [markdown]
# ---

# %% [markdown]
# ### Importación de librerias

# %%
# Tratamiento de datos
# ==============================================================================
import pandas as pd
import numpy as np

# Gráficos
# ==============================================================================
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocesado y modelado
# ==============================================================================
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.decomposition import PCA   
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import GradientBoostingClassifier
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder

# Importar para guardar y cargar el modelo
import pickle

# Configuración warnings
# ==============================================================================
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Carga de datos

# %%
df1 = pd.read_csv('../data/sleep_disorder_dataset.csv')

df1
# Out:
#     Patient_ID  Age  Gender      Sleep_Disorder_Type  AHI_Score  SaO2_Level  \
# 0        P0001   54  Female    Restless Leg Syndrome      44.11       77.59
# 1        P0002   17  Female    Restless Leg Syndrome      33.55       76.22
# 2        P0003   74    Male                 Insomnia      12.91       89.53
# 3        P0004   63    Male    Restless Leg Syndrome      33.73       85.65
# 4        P0005   23  Female                 Insomnia      14.84       88.70
# ..         ...  ...     ...                      ...        ...         ...
# 995      P0996   23  Female                 Insomnia      41.57       83.14
# 996      P0997   49  Female              No Disorder      42.12       84.85
# 997      P0998   75    Male  Obstructive Sleep Apnea      18.66       90.08
# 998      P0999   55  Female                 Insomnia      31.60       95.04
# 999      P1000   11  Female    Restless Leg Syndrome       4.77       86.74
#
#                                     OCR_Extracted_Text  Diagnosis_Confirmed
# 0    Patient P0001 diagnosed with Restless Leg Synd...                    1
# 1    Patient P0002 diagnosed with Restless Leg Synd...                    1
# 2               Patient P0003 diagnosed with Insomnia.                    1
# 3    Patient P0004 diagnosed with Restless Leg Synd...                    1
# 4               Patient P0005 diagnosed with Insomnia.                    1
# ..                                                 ...                  ...
# 995             Patient P0996 diagnosed with Insomnia.                    1
# 996          Patient P0997 diagnosed with No Disorder.                    1
# 997  Patient P0998 diagnosed with Obstructive Sleep...                    1
# 998             Patient P0999 diagnosed with Insomnia.                    1
# 999  Patient P1000 diagnosed with Restless Leg Synd...                    1
#
# [1000 rows x 8 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Patient_ID           1000 non-null   object
#  1   Age                  1000 non-null   int64
#  2   Gender               1000 non-null   object
#  3   Sleep_Disorder_Type  1000 non-null   object
#  4   AHI_Score            1000 non-null   float64
#  5   SaO2_Level           1000 non-null   float64
#  6   OCR_Extracted_Text   1000 non-null   object
#  7   Diagnosis_Confirmed  1000 non-null   int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 62.6+ KB

# %% [markdown]
# ---

# %%
df2 = pd.read_csv('../data/Sleep_health_and_lifestyle_dataset.csv')
df2
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# 1                   6                       60             8       Normal
# 2                   6                       60             8       Normal
# 3                   4                       30             8        Obese
# 4                   4                       30             8        Obese
# ..                ...                      ...           ...          ...
# 369                 9                       75             3   Overweight
# 370                 9                       75             3   Overweight
# 371                 9                       75             3   Overweight
# 372                 9                       75             3   Overweight
# 373                 9                       75             3   Overweight
#
#     Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0           126/83          77         4200            NaN
# 1           125/80          75        10000            NaN
# 2           125/80          75        10000            NaN
# 3           140/90          85         3000    Sleep Apnea
# 4           140/90          85         3000    Sleep Apnea
# ..             ...         ...          ...            ...
# 369         140/95          68         7000    Sleep Apnea
# 370         140/95          68         7000    Sleep Apnea
# 371         140/95          68         7000    Sleep Apnea
# 372         140/95          68         7000    Sleep Apnea
# 373         140/95          68         7000    Sleep Apnea
#
# [374 rows x 13 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %% [markdown]
# ---

# %%
# Hacemos un merge de los dos dataframes
# en base a las columnas 'Age' y 'Gender'
# Se hace un merge a la izquierda para que no se pierdan datos de df1

df_combined = pd.merge(df2, df1, how='left', left_on=['Age', 'Gender'], right_on=['Age', 'Gender'])

# %%
df_combined
# Out:
#       Person ID  Gender  Age         Occupation  Sleep Duration  \
# 0             1    Male   27  Software Engineer             6.1
# 1             1    Male   27  Software Engineer             6.1
# 2             1    Male   27  Software Engineer             6.1
# 3             1    Male   27  Software Engineer             6.1
# 4             1    Male   27  Software Engineer             6.1
# ...         ...     ...  ...                ...             ...
# 2251        374  Female   59              Nurse             8.1
# 2252        374  Female   59              Nurse             8.1
# 2253        374  Female   59              Nurse             8.1
# 2254        374  Female   59              Nurse             8.1
# 2255        374  Female   59              Nurse             8.1
#
#       Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                    6                       42             6   Overweight
# 1                    6                       42             6   Overweight
# 2                    6                       42             6   Overweight
# 3                    6                       42             6   Overweight
# 4                    6                       42             6   Overweight
# ...                ...                      ...           ...          ...
# 2251                 9                       75             3   Overweight
# 2252                 9                       75             3   Overweight
# 2253                 9                       75             3   Overweight
# 2254                 9                       75             3   Overweight
# 2255                 9                       75             3   Overweight
#
#      Blood Pressure  Heart Rate  Daily Steps Sleep Disorder Patient_ID  \
# 0            126/83          77         4200            NaN      P0321
# 1            126/83          77         4200            NaN      P0340
# 2            126/83          77         4200            NaN      P0489
# 3            126/83          77         4200            NaN      P0611
# 4            126/83          77         4200            NaN      P0708
# ...             ...         ...          ...            ...        ...
# 2251         140/95          68         7000    Sleep Apnea      P0569
# 2252         140/95          68         7000    Sleep Apnea      P0580
# 2253         140/95          68         7000    Sleep Apnea      P0814
# 2254         140/95          68         7000    Sleep Apnea      P0924
# 2255         140/95          68         7000    Sleep Apnea      P0989
#
#           Sleep_Disorder_Type  AHI_Score  SaO2_Level  \
# 0                  Narcolepsy      47.20       98.11
# 1     Obstructive Sleep Apnea      18.56       91.75
# 2                    Insomnia      42.71       78.61
# 3     Obstructive Sleep Apnea      27.12       82.61
# 4                    Insomnia      49.10       76.13
# ...                       ...        ...         ...
# 2251    Restless Leg Syndrome       4.75       82.91
# 2252                 Insomnia      46.55       98.58
# 2253  Obstructive Sleep Apnea      14.17       83.15
# 2254  Obstructive Sleep Apnea      33.95       91.90
# 2255               Narcolepsy      35.33       97.89
#
#                                      OCR_Extracted_Text  Diagnosis_Confirmed
# 0              Patient P0321 diagnosed with Narcolepsy.                    1
# 1     Patient P0340 diagnosed with Obstructive Sleep...                    1
# 2                Patient P0489 diagnosed with Insomnia.                    1
# 3     Patient P0611 diagnosed with Obstructive Sleep...                    1
# 4                Patient P0708 diagnosed with Insomnia.                    1
# ...                                                 ...                  ...
# 2251  Patient P0569 diagnosed with Restless Leg Synd...                    1
# 2252             Patient P0580 diagnosed with Insomnia.                    1
# 2253  Patient P0814 diagnosed with Obstructive Sleep...                    1
# 2254  Patient P0924 diagnosed with Obstructive Sleep...                    1
# 2255           Patient P0989 diagnosed with Narcolepsy.                    1
#
# [2256 rows x 19 columns]

# %%
# comprobar los nulos
df_combined.isnull().sum()
# Out:
# Person ID                     0
# Gender                        0
# Age                           0
# Occupation                    0
# Sleep Duration                0
# Quality of Sleep              0
# Physical Activity Level       0
# Stress Level                  0
# BMI Category                  0
# Blood Pressure                0
# Heart Rate                    0
# Daily Steps                   0
# Sleep Disorder             1383
# Patient_ID                    0
# Sleep_Disorder_Type           0
# AHI_Score                     0
# SaO2_Level                    0
# OCR_Extracted_Text            0
# Diagnosis_Confirmed           0
# dtype: int64

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2256 entries, 0 to 2255
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                2256 non-null   int64
#  1   Gender                   2256 non-null   object
#  2   Age                      2256 non-null   int64
#  3   Occupation               2256 non-null   object
#  4   Sleep Duration           2256 non-null   float64
#  5   Quality of Sleep         2256 non-null   int64
#  6   Physical Activity Level  2256 non-null   int64
#  7   Stress Level             2256 non-null   int64
#  8   BMI Category             2256 non-null   object
#  9   Blood Pressure           2256 non-null   object
#  10  Heart Rate               2256 non-null   int64
#  11  Daily Steps              2256 non-null   int64
#  12  Sleep Disorder           873 non-null    object
#  13  Patient_ID               2256 non-null   object
#  14  Sleep_Disorder_Type      2256 non-null   object
#  15  AHI_Score                2256 non-null   float64
#  16  SaO2_Level               2256 non-null   float64
#  17  OCR_Extracted_Text       2256 non-null   object
#  18  Diagnosis_Confirmed      2256 non-null   int64
# dtypes: float64(3), int64(8), object(8)
# memory usage: 335.0+ KB

# %%
df_combined.describe()
# Out:
#          Person ID          Age  Sleep Duration  Quality of Sleep  \
# count  2256.000000  2256.000000     2256.000000       2256.000000
# mean    193.944149    42.753546        7.196321          7.433954
# std     108.471417     8.703466        0.817139          1.240513
# min       1.000000    27.000000        5.800000          4.000000
# 25%     101.000000    36.000000        6.400000          6.000000
# 50%     186.000000    42.000000        7.200000          8.000000
# 75%     294.000000    50.000000        7.900000          8.000000
# max     374.000000    59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level   Heart Rate   Daily Steps  \
# count              2256.000000   2256.000000  2256.000000   2256.000000
# mean                 58.311170      5.223848    70.064716   6726.462766
# std                  21.057787      1.813470     4.370560   1682.552987
# min                  30.000000      3.000000    65.000000   3000.000000
# 25%                  42.000000      4.000000    68.000000   5000.000000
# 50%                  60.000000      5.000000    70.000000   7000.000000
# 75%                  75.000000      7.000000    72.000000   8000.000000
# max                  90.000000      8.000000    86.000000  10000.000000
#
#          AHI_Score   SaO2_Level  Diagnosis_Confirmed
# count  2256.000000  2256.000000          2256.000000
# mean     26.268324    87.878785             0.856383
# std      14.999625     7.303265             0.350779
# min       0.020000    75.000000             0.000000
# 25%      12.190000    82.060000             1.000000
# 50%      26.600000    87.150000             1.000000
# 75%      38.820000    94.620000             1.000000
# max      49.990000    99.940000             1.000000

# %%
# Obtener los tipos de datos
print(df_combined.dtypes)
# Out:
# Person ID                    int64
# Gender                      object
# Age                          int64
# Occupation                  object
# Sleep Duration             float64
# Quality of Sleep             int64
# Physical Activity Level      int64
# Stress Level                 int64
# BMI Category                object
# Blood Pressure              object
# Heart Rate                   int64
# Daily Steps                  int64
# Sleep Disorder              object
# Patient_ID                  object
# Sleep_Disorder_Type         object
# AHI_Score                  float64
# SaO2_Level                 float64
# OCR_Extracted_Text          object
# Diagnosis_Confirmed          int64
# dtype: object

# %%
# combinar las 2 columans de trastornos del sueño
df_combined['Combined_Sleep_Disorder'] = df_combined['Sleep Disorder'].combine_first(df_combined['Sleep_Disorder_Type'])

# %%
# Eliminar las columnas originales, ya no hacen falta
df_combined = df_combined.drop(columns=['Sleep Disorder', 'Sleep_Disorder_Type'])

# %%
df_combined.isnull().sum()
# Out:
# Person ID                  0
# Gender                     0
# Age                        0
# Occupation                 0
# Sleep Duration             0
# Quality of Sleep           0
# Physical Activity Level    0
# Stress Level               0
# BMI Category               0
# Blood Pressure             0
# Heart Rate                 0
# Daily Steps                0
# Patient_ID                 0
# AHI_Score                  0
# SaO2_Level                 0
# OCR_Extracted_Text         0
# Diagnosis_Confirmed        0
# Combined_Sleep_Disorder    0
# dtype: int64

# %%
# renombrar la columna a Sleep_disorder
df_combined.rename(columns={'Combined_Sleep_Disorder': 'Sleep_disorder'}, inplace=True)

# %%
df_combined
# Out:
#       Person ID  Gender  Age         Occupation  Sleep Duration  \
# 0             1    Male   27  Software Engineer             6.1
# 1             1    Male   27  Software Engineer             6.1
# 2             1    Male   27  Software Engineer             6.1
# 3             1    Male   27  Software Engineer             6.1
# 4             1    Male   27  Software Engineer             6.1
# ...         ...     ...  ...                ...             ...
# 2251        374  Female   59              Nurse             8.1
# 2252        374  Female   59              Nurse             8.1
# 2253        374  Female   59              Nurse             8.1
# 2254        374  Female   59              Nurse             8.1
# 2255        374  Female   59              Nurse             8.1
#
#       Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                    6                       42             6   Overweight
# 1                    6                       42             6   Overweight
# 2                    6                       42             6   Overweight
# 3                    6                       42             6   Overweight
# 4                    6                       42             6   Overweight
# ...                ...                      ...           ...          ...
# 2251                 9                       75             3   Overweight
# 2252                 9                       75             3   Overweight
# 2253                 9                       75             3   Overweight
# 2254                 9                       75             3   Overweight
# 2255                 9                       75             3   Overweight
#
#      Blood Pressure  Heart Rate  Daily Steps Patient_ID  AHI_Score  \
# 0            126/83          77         4200      P0321      47.20
# 1            126/83          77         4200      P0340      18.56
# 2            126/83          77         4200      P0489      42.71
# 3            126/83          77         4200      P0611      27.12
# 4            126/83          77         4200      P0708      49.10
# ...             ...         ...          ...        ...        ...
# 2251         140/95          68         7000      P0569       4.75
# 2252         140/95          68         7000      P0580      46.55
# 2253         140/95          68         7000      P0814      14.17
# 2254         140/95          68         7000      P0924      33.95
# 2255         140/95          68         7000      P0989      35.33
#
#       SaO2_Level                                 OCR_Extracted_Text  \
# 0          98.11           Patient P0321 diagnosed with Narcolepsy.
# 1          91.75  Patient P0340 diagnosed with Obstructive Sleep...
# 2          78.61             Patient P0489 diagnosed with Insomnia.
# 3          82.61  Patient P0611 diagnosed with Obstructive Sleep...
# 4          76.13             Patient P0708 diagnosed with Insomnia.
# ...          ...                                                ...
# 2251       82.91  Patient P0569 diagnosed with Restless Leg Synd...
# 2252       98.58             Patient P0580 diagnosed with Insomnia.
# 2253       83.15  Patient P0814 diagnosed with Obstructive Sleep...
# 2254       91.90  Patient P0924 diagnosed with Obstructive Sleep...
# 2255       97.89           Patient P0989 diagnosed with Narcolepsy.
#
#       Diagnosis_Confirmed           Sleep_disorder
# 0                       1               Narcolepsy
# 1                       1  Obstructive Sleep Apnea
# 2                       1                 Insomnia
# 3                       1  Obstructive Sleep Apnea
# 4                       1                 Insomnia
# ...                   ...                      ...
# 2251                    1              Sleep Apnea
# 2252                    1              Sleep Apnea
# 2253                    1              Sleep Apnea
# 2254                    1              Sleep Apnea
# 2255                    1              Sleep Apnea
#
# [2256 rows x 18 columns]

# %%
# Verificar el balance de la columna target 'Sleep Disorder'
print(df_combined['Sleep_disorder'].value_counts(dropna=False))
# Out:
# Sleep_disorder
# Insomnia                   757
# Obstructive Sleep Apnea    492
# Sleep Apnea                490
# Restless Leg Syndrome      213
# Narcolepsy                 187
# No Disorder                117
# Name: count, dtype: int64

# %% [markdown]
# #### Explicación de Tipos de trastornos
# - Insomnia → Insomnio. Dificultad para conciliar el sueño, permanecer dormido o despertarse demasiado temprano y no poder volver a dormir.
# - Obstructive Sleep Apnea (OSA) → Apnea Obstructiva del Sueño. Trastorno en el que la respiración se interrumpe repetidamente durante el sueño debido a una obstrucción de las vías respiratorias.
# - Slep Apnea → Cualquier tipo de apnea del sueño. (OSA) y (CSA)
# - Restless Leg Syndrome → Síndrome de Piernas Inquietas. Trastorno neurológico caracterizado por una necesidad incontrolable de mover las piernas, especialmente por la noche.
# - Narcolepsy → Narcolepsia. Trastorno del sueño que provoca somnolencia extrema durante el día y episodios súbitos de sueño.
# - No Disorder → Sin Trastorno. Pacientes que no presentan ningún trastorno del sueño diagnosticado.
# ---

# %%
# Eliminar la columna OCR_Extracted_Text, no me aporta información
df_combined = df_combined.drop(columns=['OCR_Extracted_Text'])

# %%
# Asegúrate de que 'Sleep_disorder' contiene strings, no números
print(df_combined['Sleep_disorder'].unique())

# Crear y aplicar LabelEncoder
sleep_encoder = LabelEncoder()
df_combined['Sleep_disorder_encoded'] = sleep_encoder.fit_transform(df_combined['Sleep_disorder'])

# Ver mapeo: nombre del trastorno → número
sleep_disorder_mapping = dict(zip(sleep_encoder.classes_, sleep_encoder.transform(sleep_encoder.classes_)))
print("Nombre → Número:")
print(sleep_disorder_mapping)

# Ver mapeo inverso: número → nombre
inverse_mapping = {v: k for k, v in sleep_disorder_mapping.items()}
print("Número → Nombre:")
print(inverse_mapping)
# Out:
# ['Narcolepsy' 'Obstructive Sleep Apnea' 'Insomnia' 'Restless Leg Syndrome'
#  'Sleep Apnea' 'No Disorder']
# Nombre → Número:
# {'Insomnia': np.int64(0), 'Narcolepsy': np.int64(1), 'No Disorder': np.int64(2), 'Obstructive Sleep Apnea': np.int64(3), 'Restless Leg Syndrome': np.int64(4), 'Sleep Apnea': np.int64(5)}
# Número → Nombre:
# {np.int64(0): 'Insomnia', np.int64(1): 'Narcolepsy', np.int64(2): 'No Disorder', np.int64(3): 'Obstructive Sleep Apnea', np.int64(4): 'Restless Leg Syndrome', np.int64(5): 'Sleep Apnea'}

# %% [markdown]
# - Nombre → Número:
# {
#     'Insomnia': 0,
#     'Narcolepsy': 1,
#     'No Disorder': 2,
#     'Obstructive Sleep Apnea': 3,
#     'Restless Leg Syndrome': 4,
#     'Sleep Apnea': 5
# }
#
# - Número → Nombre:
# {
#     0: 'Insomnia',
#     1: 'Narcolepsy',
#     2: 'No Disorder',
#     3: 'Obstructive Sleep Apnea',
#     4: 'Restless Leg Syndrome',
#     5: 'Sleep Apnea'
# }

# %%
# Comprobación de los tipos de datos
print(df_combined.dtypes)
# Out:
# Person ID                    int64
# Gender                      object
# Age                          int64
# Occupation                  object
# Sleep Duration             float64
# Quality of Sleep             int64
# Physical Activity Level      int64
# Stress Level                 int64
# BMI Category                object
# Blood Pressure              object
# Heart Rate                   int64
# Daily Steps                  int64
# Patient_ID                  object
# AHI_Score                  float64
# SaO2_Level                 float64
# Diagnosis_Confirmed          int64
# Sleep_disorder              object
# Sleep_disorder_encoded       int64
# dtype: object

# %%
df_combined
# Out:
#       Person ID  Gender  Age         Occupation  Sleep Duration  \
# 0             1    Male   27  Software Engineer             6.1
# 1             1    Male   27  Software Engineer             6.1
# 2             1    Male   27  Software Engineer             6.1
# 3             1    Male   27  Software Engineer             6.1
# 4             1    Male   27  Software Engineer             6.1
# ...         ...     ...  ...                ...             ...
# 2251        374  Female   59              Nurse             8.1
# 2252        374  Female   59              Nurse             8.1
# 2253        374  Female   59              Nurse             8.1
# 2254        374  Female   59              Nurse             8.1
# 2255        374  Female   59              Nurse             8.1
#
#       Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                    6                       42             6   Overweight
# 1                    6                       42             6   Overweight
# 2                    6                       42             6   Overweight
# 3                    6                       42             6   Overweight
# 4                    6                       42             6   Overweight
# ...                ...                      ...           ...          ...
# 2251                 9                       75             3   Overweight
# 2252                 9                       75             3   Overweight
# 2253                 9                       75             3   Overweight
# 2254                 9                       75             3   Overweight
# 2255                 9                       75             3   Overweight
#
#      Blood Pressure  Heart Rate  Daily Steps Patient_ID  AHI_Score  \
# 0            126/83          77         4200      P0321      47.20
# 1            126/83          77         4200      P0340      18.56
# 2            126/83          77         4200      P0489      42.71
# 3            126/83          77         4200      P0611      27.12
# 4            126/83          77         4200      P0708      49.10
# ...             ...         ...          ...        ...        ...
# 2251         140/95          68         7000      P0569       4.75
# 2252         140/95          68         7000      P0580      46.55
# 2253         140/95          68         7000      P0814      14.17
# 2254         140/95          68         7000      P0924      33.95
# 2255         140/95          68         7000      P0989      35.33
#
#       SaO2_Level  Diagnosis_Confirmed           Sleep_disorder  \
# 0          98.11                    1               Narcolepsy
# 1          91.75                    1  Obstructive Sleep Apnea
# 2          78.61                    1                 Insomnia
# 3          82.61                    1  Obstructive Sleep Apnea
# 4          76.13                    1                 Insomnia
# ...          ...                  ...                      ...
# 2251       82.91                    1              Sleep Apnea
# 2252       98.58                    1              Sleep Apnea
# 2253       83.15                    1              Sleep Apnea
# 2254       91.90                    1              Sleep Apnea
# 2255       97.89                    1              Sleep Apnea
#
#       Sleep_disorder_encoded
# 0                          1
# 1                          3
# 2                          0
# 3                          3
# 4                          0
# ...                      ...
# 2251                       5
# 2252                       5
# 2253                       5
# 2254                       5
# 2255                       5
#
# [2256 rows x 18 columns]

# %%
# Identificar columnas categóricas
categorical_columns = df_combined.select_dtypes(include=['object']).columns

# Aplicar LabelEncoder a cada columna categórica
label_encoders = {}
for column in categorical_columns:
    le = LabelEncoder()
    df_combined[column] = le.fit_transform(df_combined[column])
    label_encoders[column] = le

# Verificar la conversión
print(df_combined.head())
# Out:
#    Person ID  Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0          1       1   27           9             6.1                 6
# 1          1       1   27           9             6.1                 6
# 2          1       1   27           9             6.1                 6
# 3          1       1   27           9             6.1                 6
# 4          1       1   27           9             6.1                 6
#
#    Physical Activity Level  Stress Level  BMI Category  Blood Pressure  \
# 0                       42             6             3              11
# 1                       42             6             3              11
# 2                       42             6             3              11
# 3                       42             6             3              11
# 4                       42             6             3              11
#
#    Heart Rate  Daily Steps  Patient_ID  AHI_Score  SaO2_Level  \
# 0          77         4200          88      47.20       98.11
# 1          77         4200          90      18.56       91.75
# 2          77         4200         126      42.71       78.61
# 3          77         4200         164      27.12       82.61
# 4          77         4200         192      49.10       76.13
#
#    Diagnosis_Confirmed  Sleep_disorder  Sleep_disorder_encoded
# 0                    1               1                       1
# 1                    1               3                       3
# 2                    1               0                       0
# 3                    1               3                       3
# 4                    1               0                       0

# %%
# La columna Sleep disorder encoded eliminarla, ya no es necesaria
df_combined = df_combined.drop(columns=['Sleep_disorder_encoded'])

# %%
df_combined
# Out:
#       Person ID  Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0             1       1   27           9             6.1                 6
# 1             1       1   27           9             6.1                 6
# 2             1       1   27           9             6.1                 6
# 3             1       1   27           9             6.1                 6
# 4             1       1   27           9             6.1                 6
# ...         ...     ...  ...         ...             ...               ...
# 2251        374       0   59           5             8.1                 9
# 2252        374       0   59           5             8.1                 9
# 2253        374       0   59           5             8.1                 9
# 2254        374       0   59           5             8.1                 9
# 2255        374       0   59           5             8.1                 9
#
#       Physical Activity Level  Stress Level  BMI Category  Blood Pressure  \
# 0                          42             6             3              11
# 1                          42             6             3              11
# 2                          42             6             3              11
# 3                          42             6             3              11
# 4                          42             6             3              11
# ...                       ...           ...           ...             ...
# 2251                       75             3             3              23
# 2252                       75             3             3              23
# 2253                       75             3             3              23
# 2254                       75             3             3              23
# 2255                       75             3             3              23
#
#       Heart Rate  Daily Steps  Patient_ID  AHI_Score  SaO2_Level  \
# 0             77         4200          88      47.20       98.11
# 1             77         4200          90      18.56       91.75
# 2             77         4200         126      42.71       78.61
# 3             77         4200         164      27.12       82.61
# 4             77         4200         192      49.10       76.13
# ...          ...          ...         ...        ...         ...
# 2251          68         7000         148       4.75       82.91
# 2252          68         7000         152      46.55       98.58
# 2253          68         7000         220      14.17       83.15
# 2254          68         7000         255      33.95       91.90
# 2255          68         7000         283      35.33       97.89
#
#       Diagnosis_Confirmed  Sleep_disorder
# 0                       1               1
# 1                       1               3
# 2                       1               0
# 3                       1               3
# 4                       1               0
# ...                   ...             ...
# 2251                    1               5
# 2252                    1               5
# 2253                    1               5
# 2254                    1               5
# 2255                    1               5
#
# [2256 rows x 17 columns]

# %%
print(df_combined.dtypes)
# Out:
# Person ID                    int64
# Gender                       int64
# Age                          int64
# Occupation                   int64
# Sleep Duration             float64
# Quality of Sleep             int64
# Physical Activity Level      int64
# Stress Level                 int64
# BMI Category                 int64
# Blood Pressure               int64
# Heart Rate                   int64
# Daily Steps                  int64
# Patient_ID                   int64
# AHI_Score                  float64
# SaO2_Level                 float64
# Diagnosis_Confirmed          int64
# Sleep_disorder               int64
# dtype: object

# %%
# Guardar el dataframe combinado
df_combined.to_csv('../data/combined_sleep_dataset.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# #### Análisis Univariante

# %%
# Configuración visual
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)

# Lista de variables numéricas
num_cols = ['Age', 'AHI_Score', 'SaO2_Level']

# Histograma para cada variable numérica
for col in num_cols:
    plt.figure()
    sns.histplot(df_combined[col], kde=True, bins=30, color='skyblue')
    plt.title(f'Distribución de {col}')
    plt.xlabel(col)
    plt.ylabel('Frecuencia')
    plt.show()

# Estadísticas descriptivas
df_combined[num_cols].describe()
# Out:
#                Age    AHI_Score   SaO2_Level
# count  2256.000000  2256.000000  2256.000000
# mean     42.753546    26.268324    87.878785
# std       8.703466    14.999625     7.303265
# min      27.000000     0.020000    75.000000
# 25%      36.000000    12.190000    82.060000
# 50%      42.000000    26.600000    87.150000
# 75%      50.000000    38.820000    94.620000
# max      59.000000    49.990000    99.940000

# %%
# Lista de variables categóricas
cat_cols = ['Gender', 'Sleep_disorder', 'Diagnosis_Confirmed']

# Gráficos de barras para variables categóricas
for col in cat_cols:
    plt.figure()
    sns.countplot(data=df_combined, x=col, palette='pastel')
    plt.title(f'Frecuencia de {col}')
    plt.xlabel(col)
    plt.ylabel('Conteo')
    plt.xticks()
    plt.show()

# Conteo de categorías
for col in cat_cols:
    print(f"\nConteo de {col}:\n", df_combined[col].value_counts())
# Out:
# Conteo de Gender:
#  Gender
# 0    1222
# 1    1034
# Name: count, dtype: int64
#
# Conteo de Sleep_disorder:
#  Sleep_disorder
# 0    757
# 3    492
# 5    490
# 4    213
# 1    187
# 2    117
# Name: count, dtype: int64
#
# Conteo de Diagnosis_Confirmed:
#  Diagnosis_Confirmed
# 1    1932
# 0     324
# Name: count, dtype: int64

# %% [markdown]
# ----

# %% [markdown]
# ### Análisis Bivariante

# %%
# Crear una figura de subplots (2 filas, 3 columnas)
fig, axes = plt.subplots(2, 3, figsize=(20, 10))

# -----------------------------------------
# 1. Función de densidad (KDE) sola
sns.kdeplot(df_combined['AHI_Score'], fill=True, ax=axes[0, 0])
axes[0, 0].set_title("Función de densidad de AHI_Score")

# -----------------------------------------
# 2. Histograma solo
sns.histplot(df_combined['AHI_Score'], kde=False, color='slategray', ax=axes[0, 1])
axes[0, 1].set_title("Histograma de AHI_Score")

# -----------------------------------------
# 3. Histograma + función de densidad
sns.histplot(df_combined['AHI_Score'], kde=True, color='green', ax=axes[0, 2])
axes[0, 2].set_title("Histograma + KDE de AHI_Score")

# -----------------------------------------
# 4. Boxplot
sns.boxplot(x=df_combined['AHI_Score'], color="slategray", ax=axes[1, 0])
axes[1, 0].set_title("Boxplot de AHI_Score")

# -----------------------------------------
# 5. Violin plot
sns.violinplot(x=df_combined['AHI_Score'], color="slategray", ax=axes[1, 1])
axes[1, 1].set_title("Violin Plot de AHI_Score")

# -----------------------------------------
# 6. Función de densidad según tipo de trastorno
sns.kdeplot(data=df_combined, x='AHI_Score', hue='Sleep_disorder', ax=axes[1, 2], fill=True)
axes[1, 2].set_title("Densidad de AHI_Score según Trastorno del Sueño")

# Ajustes finales
plt.tight_layout()
plt.show()

# %%
# Pairplot: variables numéricas vs tipo de trastorno del sueño
sns.pairplot(df_combined, hue='Sleep_disorder', vars=['Age', 'AHI_Score', 'SaO2_Level'])
plt.show()

# %%
# Género vs. Tipo de Trastorno

plt.figure(figsize=(10, 6))
sns.countplot(data=df_combined, x='Sleep_disorder', hue='Gender', palette='pastel')
plt.title('Frecuencia de Trastornos del Sueño por Género')
plt.xlabel('Tipo de Trastorno del Sueño')
plt.ylabel('Conteo')
plt.legend(title='Género')

plt.tight_layout()
plt.show()

# %% [markdown]
# - 0: Insomic
# - 1: Narcolepsy
# - 2: No Disorder
# - 3 Apnea (OSA)
# - 4: Leg Syndrome
# - 5: Sleep Apnea

# %%
# matriz de correlación
plt.figure(figsize=(12, 8))
correlation_matrix = df_combined.corr()

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True, cbar_kws={"shrink": .8})
# Out:
# <Axes: >

# %% [markdown]
# ---
